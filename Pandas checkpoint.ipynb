# %%
import pandas as pd
import numpy as np
names=["ali", "hayani", "mounir"]
occurence= [16, 45, 785]
occurence2= [15, 55, 88]
print(occurence + occurence2)
# Out:
# [16, 45, 785, 15, 55, 88]

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data)
df
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df1=df.head(3)
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes

# %%
df2= df.dropna()
df2
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df.iloc[:, 0:2]
# Out:
#         name  score
# 0  Anastasia   12.5
# 1       Dima    9.0
# 2  Katherine   16.5
# 4      Emily    9.0
# 5    Michael   20.0
# 6    Matthew   14.5
# 8      Kevin    8.0
# 9      Jonas   19.0

# %%
row = pd.Series({'name':'Suresh', 'score':15.5,  'attempts':1, 'qualify': 'yes'},name="k")
df5 = df.append(row)
df5
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15852\2138344725.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5 = df.append(row)
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes

# %%
success = []
for i,row in df5.iterrows():
    if row["score"]>10:
        success.append(1)
    else:
        success.append(0)
df5["success"] = success
df5
# Out:
#         name  score  attempts qualify  success
# 0  Anastasia   12.5         1     yes        1
# 1       Dima    9.0         3      no        0
# 2  Katherine   16.5         2     yes        1
# 4      Emily    9.0         2      no        0
# 5    Michael   20.0         3     yes        1
# 6    Matthew   14.5         1     yes        1
# 8      Kevin    8.0         2      no        0
# 9      Jonas   19.0         1     yes        1
# k     Suresh   15.5         1     yes        1

# %%
df.pop('attempts')
df
# Out:
#         name  score qualify
# 0  Anastasia   12.5     yes
# 1       Dima    9.0      no
# 2  Katherine   16.5     yes
# 4      Emily    9.0      no
# 5    Michael   20.0     yes
# 6    Matthew   14.5     yes
# 8      Kevin    8.0      no
# 9      Jonas   19.0     yes

# %%
gfg_csv_data = df.to_csv('GfG.csv', index = True)
print('\nCSV String:\n', gfg_csv_data)
# Out:
# CSV String:
#  None
